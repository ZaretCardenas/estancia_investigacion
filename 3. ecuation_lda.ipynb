# %%
import pyLDAvis.gensim
import pyLDAvis
import gensim
import os 
os.environ["TOKENIZERS_PARALLELISM"] = "false"
import pickle
from gensim.models import CoherenceModel


def ecuation_show(root,model_type):
    dictionary = gensim.corpora.Dictionary.load(f'{root}{model_type}_dictionary.gensim')
    corpus = pickle.load(open(f'{root}{model_type}_corpus.pkl', 'rb'))
    lda = gensim.models.ldamodel.LdaModel.load(f'{root}{model_type}_model.gensim')
    topics = lda.print_topics()
    for topic in topics:
        print(topic)

print('investors lda by gender etrepenur H')
root ='4_exp_lda_all_text/lda/'
model_type='h_key'
ecuation_show(root,model_type)

print('investors lda by gender etrepenur M')
root ='4_exp_lda_all_text_final/lda/'
model_type='m_key'
ecuation_show(root,model_type)

print('investors lda by gender etrepenur M v2')
root ='4_exp_lda_all_text_final/lda/'
model_type='m_key'
ecuation_show(root,model_type)

print('investors lda by gender inv H')
root ='6_exp_lda_all_text_by_shark_gender/lda/'
model_type='h_key'
ecuation_show(root,model_type)

print('investors lda by gender inv M')
root ='6_exp_lda_all_text_by_shark_gender/lda/'
model_type='m_key'
ecuation_show(root,model_type)


print('investors lda by gender inv M')
root ='10_exp_lda_all_text_final_2025/lda/'
model_type='m_key'
ecuation_show(root,model_type)

print('investors lda by gender inv M')
root ='10_exp_lda_all_text_final_2025_eta/lda/'
model_type='m_key'
ecuation_show(root,model_type)
# Out:
# investors lda by gender etrepenur H
# (0, '0.023*"product" + 0.014*"sell" + 0.011*"company" + 0.010*"offer" + 0.010*"business" + 0.008*"brand" + 0.008*"sale" + 0.008*"reason" + 0.008*"take" + 0.007*"mean"')
# (1, '0.017*"valuation" + 0.015*"offer" + 0.009*"sell" + 0.009*"product" + 0.008*"project" + 0.008*"company" + 0.008*"understand" + 0.007*"sale" + 0.007*"market" + 0.007*"time"')
# (2, '0.014*"offer" + 0.013*"sale" + 0.012*"product" + 0.008*"brand" + 0.008*"valuation" + 0.007*"sell" + 0.007*"time" + 0.006*"reason" + 0.006*"take" + 0.006*"talk"')
# investors lda by gender etrepenur M
# (0, '0.016*"sale" + 0.009*"product" + 0.009*"reason" + 0.009*"cost" + 0.009*"business" + 0.007*"entrepreneur" + 0.006*"work" + 0.006*"talk" + 0.006*"sell" + 0.006*"mean"')
# (1, '0.011*"valuation" + 0.010*"project" + 0.010*"assessment" + 0.008*"loan" + 0.008*"company" + 0.007*"problem" + 0.007*"people" + 0.007*"sell" + 0.006*"deal" + 0.006*"still"')
# ...

# %%
model_type='m_key'
dictionary = gensim.corpora.Dictionary.load(f'{root}{model_type}_dictionary.gensim')
corpus = pickle.load(open(f'{root}{model_type}_corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load(f'{root}{model_type}_model.gensim')
topics = lda.print_topics()
for topic in topics:
    print(topic)

# %%
list(enoe)
# Out:
# ['Posición en la ocupación',
#  '- Total',
#  'Empleadores',
#  'Trabajadores por cuenta propia',
#  '- Trabajadores subordinados y remunerados',
#  'no remunerados',
#  'genero']

# %%
enoe=pd.read_csv('/Users/delia.cardenas/Downloads/ENOE ocuopacion tabulado  - Hoja 2.csv')

df = pd.DataFrame(enoe)


# Agrupar por género y calcular totales
df_grouped = df.groupby("genero").sum()

# Calcular los porcentajes para cada categoría
for col in ["Empleadores", "Trabajadores por cuenta propia", "- Trabajadores subordinados y remunerados", "no remunerados"]:
    df_grouped[f"{col} (%)"] = (df_grouped[col] / df_grouped["- Total"]) * 100

# Graficar
fig, ax = plt.subplots(figsize=(10, 6))
categorias = ["Empleadores", "Trabajadores por cuenta propia", "- Trabajadores subordinados y remunerados", "no remunerados"]

# Crear barras apiladas para cada categoría
bar_width = 0.6
for i, categoria in enumerate(categorias):
    ax.bar(
        df_grouped.index,
        df_grouped[f"{categoria} (%)"],
        bottom=df_grouped[[f"{categorias[j]} (%)" for j in range(i)].sum(axis=1)] if i > 0 else None,
        label=categoria,
    )

# Configurar detalles del gráfico
ax.set_ylabel("Porcentaje (%)")
ax.set_title("Distribución porcentual por posición ocupacional y género")
ax.set_ylim(0, 100)
ax.legend(title="Categorías", bbox_to_anchor=(1.05, 1), loc="upper left")

# Mostrar los valores en las barras
for i, row in df_grouped.iterrows():
    cumulative = 0
    for categoria in categorias:
        porcentaje = row[f"{categoria} (%)"]
        cumulative += porcentaje
        ax.text(i, cumulative - porcentaje / 2, f"{porcentaje:.1f}%", ha="center", va="center", fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 23
#      18 bar_width = 0.6
#      19 for i, categoria in enumerate(categorias):
#      20     ax.bar(
#      21         df_grouped.index,
#      22         df_grouped[f"{categoria} (%)"],
# ---> 23         bottom=df_grouped[[f"{categorias[j]} (%)" for j in range(i)].sum(axis=1)] if i > 0 else None,
#      24         label=categoria,
#      25     )
#      27 # Configurar detalles del gráfico
#      28 ax.set_ylabel("Porcentaje (%)")
#
# AttributeError: 'list' object has no attribute 'sum'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos en un diccionario
data = {
    "Trimestre": [
        "Tercer trimestre del 2024", "Segundo trimestre del 2024", "Primer trimestre del 2024",
        "Cuarto trimestre del 2023", "Tercer trimestre del 2023", "Segundo trimestre del 2023",
        "Primer trimestre del 2023", "Cuarto trimestre del 2022", "Tercer trimestre del 2022",
        "Segundo trimestre del 2022", "Primer trimestre del 2022", "Tercer trimestre del 2024",
        "Segundo trimestre del 2024", "Primer trimestre del 2024", "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023", "Segundo trimestre del 2023", "Primer trimestre del 2023",
        "Cuarto trimestre del 2022", "Tercer trimestre del 2022", "Segundo trimestre del 2022",
        "Primer trimestre del 2022"
    ],
    "Total": [
        24272864, 24279108, 24049349, 24241480, 24018262, 23805405, 23605572, 23653813, 22808402, 22891895, 22081189,
        35255385, 35048053, 35071556, 35162467, 35149210, 34716585, 34886554, 34695540, 34632039, 34528782, 33997934
    ],
    "Empleadores": [
        713359, 746, 771471, 701401, 731261, 673246, 689243, 659274, 650758, 671969, 625164,
        2453901, 2444143, 2527307, 2291824, 2470847, 2396395, 2397368, 2311115, 2286594, 2314855, 2254484
    ],
    "Trabajadores por cuenta propia": [
        5523750, 5541199, 5345703, 5550858, 5465145, 5431529, 5322450, 5503388, 5268049, 5338021, 5091735,
        7634757, 7461203, 7457022, 7626448, 7673417, 7643183, 7716373, 7656655, 7832666, 7638866, 7512219
    ],
    "Trabajadores subordinados y remunerados": [
        16680615, 16722662, 16621848, 16640219, 16406284, 16347762, 16250454, 16013457, 15435367, 15518663, 15079591,
        24302079, 24311695, 24246442, 24356910, 24060045, 23772826, 23883870, 23761875, 23469660, 23688596, 23306381
    ],
    "No remunerados": [
        1355140, 1269247, 1310327, 1349002, 1415572, 1352868, 1343425, 1477694, 1454228, 1363242, 1284699,
        864648, 831012, 840785, 887285, 944901, 904181, 888943, 965895, 1043119, 886465, 92485
    ],
    "Genero": [
        "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer",
        "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre"
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Calcular los porcentajes para cada categoría
df["% Empleadores"] = df["Empleadores"] / df["Total"] * 100
df["% Trabajadores por cuenta propia"] = df["Trabajadores por cuenta propia"] / df["Total"] * 100
df["% Trabajadores subordinados y remunerados"] = df["Trabajadores subordinados y remunerados"] / df["Total"] * 100
df["% No remunerados"] = df["No remunerados"] / df["Total"] * 100

# Separar los datos por género
df_mujer = df[df["Genero"] == "mujer"]
df_hombre = df[df["Genero"] == "hombre"]

# Función para crear la gráfica
def plot_genero(data, titulo):
    categorias = ["% Empleadores", "% Trabajadores por cuenta propia", "% Trabajadores subordinados y remunerados", "% No remunerados"]
    
    data[categorias].plot(
        kind="bar", 
        stacked=True, 
        figsize=(10, 6), 
        color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"],
        alpha=0.85
    )
    plt.title(titulo, fontsize=14)
    plt.ylabel("Porcentaje (%)")
    plt.xlabel("Trimestre")
    plt.xticks(range(len(data)), data["Trimestre"], rotation=45, ha="right")
    plt.legend(loc="upper right")
    plt.tight_layout()
    plt.show()

# Graficar para mujeres y hombres
plot_genero(df_mujer, "Distribución porcentual por posición en la ocupación - Mujeres")
plot_genero(df_hombre, "Distribución porcentual por posición en la ocupación - Hombres")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos iniciales (corrección: los números no tienen "_")
data = {
    "Periodo encuesta": [
        "Tercer trimestre del 2024",
        "Segundo trimestre del 2024",
        "Primer trimestre del 2024",
        "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023",
        "Segundo trimestre del 2023",
        "Primer trimestre del 2023",
        "Cuarto trimestre del 2022",
        "Tercer trimestre del 2022",
        "Segundo trimestre del 2022",
        "Primer trimestre del 2022",
    ],
    "Total": [
        59528249, 59327161, 59120905, 59403947, 59167472, 58521990, 
        58492126, 58349353, 57440441, 57420677, 56079123
    ],
    "Trabajadores subordinados y remunerados": [
        1057332, 1014783, 1121283, 1038156, 1043185, 1052241, 
        1095391, 980490, 967528, 892889, 983097
    ],
    "Trabajadores independientes": [
        2033821, 2029216, 2147131, 2105490, 2099312, 1959350, 
        2083170, 1857280, 1783449, 1869809, 1801780
    ],
    "Trabajadores no remunerados": [
        359755, 335209, 348441, 375119, 406894, 330259, 
        348155, 357718, 377599, 356063, 328200
    ],
    "No disponen de trabajo secundario": [
        56077341, 55947953, 55504050, 55885182, 55618081, 55180140, 
        54965410, 55153865, 54311865, 54301916, 52966046
    ],
}

# Crear DataFrame
df = pd.DataFrame(data)

# Calcular porcentaje para cada columna (excepto "Periodo encuesta" y "Total")
columns = [
    "Trabajadores subordinados y remunerados",
    "Trabajadores independientes",
    "Trabajadores no remunerados",
    "No disponen de trabajo secundario",
]
df_percentage = df.copy()
for col in columns:
    df_percentage[col] = (df[col] / df["Total"]) * 100

# Visualización
fig, ax = plt.subplots(figsize=(12, 6))
df_percentage.set_index("Periodo encuesta")[columns].plot(kind="bar", stacked=True, ax=ax)
ax.set_ylabel("Porcentaje (%)")
ax.set_xlabel("Periodo de Encuesta")
ax.set_title("Distribución porcentual de ocupación secundaria por periodo")
ax.legend(title="Categorías", loc="upper right")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# Mostrar tabla de porcentajes
print("Tabla de porcentajes:")
print(df_percentage[["Periodo encuesta"] + columns])
# Out:
# Tabla de porcentajes:
#               Periodo encuesta  Trabajadores subordinados y remunerados  \
# 0    Tercer trimestre del 2024                                 1.776185
# 1   Segundo trimestre del 2024                                 1.710486
# 2    Primer trimestre del 2024                                 1.896593
# 3    Cuarto trimestre del 2023                                 1.747621
# 4    Tercer trimestre del 2023                                 1.763106
# 5   Segundo trimestre del 2023                                 1.798027
# 6    Primer trimestre del 2023                                 1.872715
# 7    Cuarto trimestre del 2022                                 1.680379
# 8    Tercer trimestre del 2022                                 1.684402
# 9   Segundo trimestre del 2022                                 1.554996
# 10   Primer trimestre del 2022                                 1.753053
#
#     Trabajadores independientes  Trabajadores no remunerados  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos en un diccionario
data = {
    "Trimestre": [
        "Tercer trimestre del 2024", "Segundo trimestre del 2024", "Primer trimestre del 2024",
        "Cuarto trimestre del 2023", "Tercer trimestre del 2023", "Segundo trimestre del 2023",
        "Primer trimestre del 2023", "Cuarto trimestre del 2022", "Tercer trimestre del 2022",
        "Segundo trimestre del 2022", "Primer trimestre del 2022", "Tercer trimestre del 2024",
        "Segundo trimestre del 2024", "Primer trimestre del 2024", "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023", "Segundo trimestre del 2023", "Primer trimestre del 2023",
        "Cuarto trimestre del 2022", "Tercer trimestre del 2022", "Segundo trimestre del 2022",
        "Primer trimestre del 2022"
    ],
    "Total": [
        24272864, 24279108, 24049349, 24241480, 24018262, 23805405, 23605572, 23653813, 22808402, 22891895, 22081189,
        35255385, 35048053, 35071556, 35162467, 35149210, 34716585, 34886554, 34695540, 34632039, 34528782, 33997934
    ],
    "Empleadores": [
        713359, 746, 771471, 701401, 731261, 673246, 689243, 659274, 650758, 671969, 625164,
        2453901, 2444143, 2527307, 2291824, 2470847, 2396395, 2397368, 2311115, 2286594, 2314855, 2254484
    ],
    "Trabajadores por cuenta propia": [
        5523750, 5541199, 5345703, 5550858, 5465145, 5431529, 5322450, 5503388, 5268049, 5338021, 5091735,
        7634757, 7461203, 7457022, 7626448, 7673417, 7643183, 7716373, 7656655, 7832666, 7638866, 7512219
    ],
    "Trabajadores subordinados y remunerados": [
        16680615, 16722662, 16621848, 16640219, 16406284, 16347762, 16250454, 16013457, 15435367, 15518663, 15079591,
        24302079, 24311695, 24246442, 24356910, 24060045, 23772826, 23883870, 23761875, 23469660, 23688596, 23306381
    ],
    "No remunerados": [
        1355140, 1269247, 1310327, 1349002, 1415572, 1352868, 1343425, 1477694, 1454228, 1363242, 1284699,
        864648, 831012, 840785, 887285, 944901, 904181, 888943, 965895, 1043119, 886465, 92485
    ],
    "Genero": [
        "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer",
        "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre"
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Sumar los totales por género
suma_por_genero = df.groupby("Genero")[["Empleadores", "Trabajadores por cuenta propia", "Trabajadores subordinados y remunerados", "No remunerados"]].sum()

# Convertir a porcentaje (normalizar por fila)
suma_por_genero_porcentajes = suma_por_genero.div(suma_por_genero.sum(axis=1), axis=0) * 100

# Graficar
ax = suma_por_genero_porcentajes.plot(
    kind="bar",
    stacked=True,
    figsize=(8, 6),
    color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"],
    alpha=0.85
)

# Agregar los porcentajes dentro de las barras
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x, y = p.get_xy()  # Get the x and y position of the rectangle
    ax.text(x + width/2, y + height/2, f'{height:.2f}%', ha='center', va='center', color='white', fontsize=10)

plt.title("Distribución porcentual por posición en la ocupación y género", fontsize=14)
plt.ylabel("Porcentaje (%)")
plt.xlabel("Género")
plt.xticks(rotation=0)
plt.legend(title="Posición en la ocupación", loc="upper left")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos en un diccionario
data = {
    "Trimestre": [
        "Tercer trimestre del 2024", "Segundo trimestre del 2024", "Primer trimestre del 2024",
        "Cuarto trimestre del 2023", "Tercer trimestre del 2023", "Segundo trimestre del 2023",
        "Primer trimestre del 2023", "Cuarto trimestre del 2022", "Tercer trimestre del 2022",
        "Segundo trimestre del 2022", "Primer trimestre del 2022", "Tercer trimestre del 2024",
        "Segundo trimestre del 2024", "Primer trimestre del 2024", "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023", "Segundo trimestre del 2023", "Primer trimestre del 2023",
        "Cuarto trimestre del 2022", "Tercer trimestre del 2022", "Segundo trimestre del 2022",
        "Primer trimestre del 2022"
    ],
    "Total": [
        24272864, 24279108, 24049349, 24241480, 24018262, 23805405, 23605572, 23653813, 22808402, 22891895, 22081189,
        35255385, 35048053, 35071556, 35162467, 35149210, 34716585, 34886554, 34695540, 34632039, 34528782, 33997934
    ],
    "Empleadores": [
        713359, 746, 771471, 701401, 731261, 673246, 689243, 659274, 650758, 671969, 625164,
        2453901, 2444143, 2527307, 2291824, 2470847, 2396395, 2397368, 2311115, 2286594, 2314855, 2254484
    ],
    "Trabajadores por cuenta propia": [
        5523750, 5541199, 5345703, 5550858, 5465145, 5431529, 5322450, 5503388, 5268049, 5338021, 5091735,
        7634757, 7461203, 7457022, 7626448, 7673417, 7643183, 7716373, 7656655, 7832666, 7638866, 7512219
    ],
    "Trabajadores subordinados y remunerados": [
        16680615, 16722662, 16621848, 16640219, 16406284, 16347762, 16250454, 16013457, 15435367, 15518663, 15079591,
        24302079, 24311695, 24246442, 24356910, 24060045, 23772826, 23883870, 23761875, 23469660, 23688596, 23306381
    ],
    "No remunerados": [
        1355140, 1269247, 1310327, 1349002, 1415572, 1352868, 1343425, 1477694, 1454228, 1363242, 1284699,
        864648, 831012, 840785, 887285, 944901, 904181, 888943, 965895, 1043119, 886465, 92485
    ],
    "Genero": [
        "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer",
        "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre"
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Sumar los totales por género
suma_por_genero = df.groupby("Genero")[["Empleadores", "Trabajadores por cuenta propia", "Trabajadores subordinados y remunerados", "No remunerados"]].sum()

# Convertir a porcentaje (normalizar por fila)
suma_por_genero_porcentajes = suma_por_genero.div(suma_por_genero.sum(axis=1), axis=0) * 100

# Graficar
ax = suma_por_genero_porcentajes.loc[["mujer"]].plot(
    kind="bar",
    stacked=True,
    figsize=(10, 6),
    color=plt.cm.Blues(range(100, 400, 75)),  # Azules más fuertes
    alpha=0.9
)

# Agregar los porcentajes dentro de las barras
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x, y = p.get_xy()
    if height > 0:
        ax.text(
            x + width / 2, 
            y + height / 2, 
            f'{height:.2f}%', 
            ha='center', 
            va='center', 
            color='white', 
            fontsize=10  # Tamaño más pequeño
        )

# Personalización
plt.title("Puesto que ocupan las Mujeres\n(como % Mujeres Ocupadas)\nEnero 2022 a Agosto 2024", fontsize=14, pad=20)
plt.ylabel("Porcentaje (%)", fontsize=12)
plt.xlabel("Género", fontsize=12)
plt.xticks(rotation=0, fontsize=12)
plt.legend(title="Posición en la ocupación", loc="lower center", bbox_to_anchor=(0.5, -0.25), ncol=2, fontsize=10)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %%
plt.cm.Blues(range(100, 400, 75))
# Out:
# array([[0.59215686, 0.77708574, 0.87643214, 1.        ],
#        [0.19538639, 0.50911188, 0.74379085, 1.        ],
#        [0.03137255, 0.20853518, 0.4497501 , 1.        ],
#        [0.03137255, 0.18823529, 0.41960784, 1.        ]])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos en un diccionario
data = {
    "Trimestre": [
        "Tercer trimestre del 2024", "Segundo trimestre del 2024", "Primer trimestre del 2024",
        "Cuarto trimestre del 2023", "Tercer trimestre del 2023", "Segundo trimestre del 2023",
        "Primer trimestre del 2023", "Cuarto trimestre del 2022", "Tercer trimestre del 2022",
        "Segundo trimestre del 2022", "Primer trimestre del 2022", "Tercer trimestre del 2024",
        "Segundo trimestre del 2024", "Primer trimestre del 2024", "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023", "Segundo trimestre del 2023", "Primer trimestre del 2023",
        "Cuarto trimestre del 2022", "Tercer trimestre del 2022", "Segundo trimestre del 2022",
        "Primer trimestre del 2022"
    ],
    "Total": [
        24272864, 24279108, 24049349, 24241480, 24018262, 23805405, 23605572, 23653813, 22808402, 22891895, 22081189,
        35255385, 35048053, 35071556, 35162467, 35149210, 34716585, 34886554, 34695540, 34632039, 34528782, 33997934
    ],
    "Empleadores": [
        713359, 746, 771471, 701401, 731261, 673246, 689243, 659274, 650758, 671969, 625164,
        2453901, 2444143, 2527307, 2291824, 2470847, 2396395, 2397368, 2311115, 2286594, 2314855, 2254484
    ],
    "Trabajadores por cuenta propia": [
        5523750, 5541199, 5345703, 5550858, 5465145, 5431529, 5322450, 5503388, 5268049, 5338021, 5091735,
        7634757, 7461203, 7457022, 7626448, 7673417, 7643183, 7716373, 7656655, 7832666, 7638866, 7512219
    ],
    "Trabajadores subordinados y remunerados": [
        16680615, 16722662, 16621848, 16640219, 16406284, 16347762, 16250454, 16013457, 15435367, 15518663, 15079591,
        24302079, 24311695, 24246442, 24356910, 24060045, 23772826, 23883870, 23761875, 23469660, 23688596, 23306381
    ],
    "No remunerados": [
        1355140, 1269247, 1310327, 1349002, 1415572, 1352868, 1343425, 1477694, 1454228, 1363242, 1284699,
        864648, 831012, 840785, 887285, 944901, 904181, 888943, 965895, 1043119, 886465, 92485
    ],
    "Genero": [
        "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer",
        "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre"
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Sumar los totales por género
suma_por_genero = df.groupby("Genero")[["Empleadores", "Trabajadores por cuenta propia", "Trabajadores subordinados y remunerados", "No remunerados"]].sum()

# Convertir a porcentaje (normalizar por fila)
suma_por_genero_porcentajes = suma_por_genero.div(suma_por_genero.sum(axis=1), axis=0) * 100

# Crear colores contrastantes en tonos pastel (incluyendo azul marino)
colors = ["#1f4e79", "#87CEEB", "#B0E0E6", "#ADD8E6"]

# Graficar
ax = suma_por_genero_porcentajes.plot(
    kind="barh",  # Gráfico de barras horizontales
    stacked=True,
    figsize=(9, 6),  # Más alto y menos ancho
    width=0.6,  # Hacer las barras más delgadas
    color=colors,
    alpha=0.9
)

# Agregar los porcentajes dentro de las barras
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    if width > 0:
        ax.text(
            x + width / 2,
            y + height / 2,
            f'{width:.1f}%',
            ha='center',
            va='center',
            color='white',
            fontsize=8
        )

# Personalización
plt.title("Puesto que ocupan las personas\n(como % Personas Ocupadas)\nEnero 2022 a Agosto 2024", fontsize=14, pad=20)
plt.xlabel("Porcentaje (%)", fontsize=10)
plt.ylabel("Género", fontsize=10, labelpad=15)
plt.xticks(fontsize=8)  # Hacer las etiquetas del eje X más pequeñas
plt.yticks(fontsize=10)  # Ajustar tamaño de las etiquetas del eje Y
plt.legend(
    title="Posición en la ocupación",
    loc="lower center",
    bbox_to_anchor=(0.5, -0.15),  # Leyenda separada debajo del gráfico
    ncol=2,
    fontsize=8
)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos en un diccionario
data = {
    "Trimestre": [
        "Tercer trimestre del 2024", "Segundo trimestre del 2024", "Primer trimestre del 2024",
        "Cuarto trimestre del 2023", "Tercer trimestre del 2023", "Segundo trimestre del 2023",
        "Primer trimestre del 2023", "Cuarto trimestre del 2022", "Tercer trimestre del 2022",
        "Segundo trimestre del 2022", "Primer trimestre del 2022", "Tercer trimestre del 2024",
        "Segundo trimestre del 2024", "Primer trimestre del 2024", "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023", "Segundo trimestre del 2023", "Primer trimestre del 2023",
        "Cuarto trimestre del 2022", "Tercer trimestre del 2022", "Segundo trimestre del 2022",
        "Primer trimestre del 2022"
    ],
    "Total": [
        24272864, 24279108, 24049349, 24241480, 24018262, 23805405, 23605572, 23653813, 22808402, 22891895, 22081189,
        35255385, 35048053, 35071556, 35162467, 35149210, 34716585, 34886554, 34695540, 34632039, 34528782, 33997934
    ],
    "Empleadores": [
        713359, 746, 771471, 701401, 731261, 673246, 689243, 659274, 650758, 671969, 625164,
        2453901, 2444143, 2527307, 2291824, 2470847, 2396395, 2397368, 2311115, 2286594, 2314855, 2254484
    ],
    "Trabajadores por cuenta propia": [
        5523750, 5541199, 5345703, 5550858, 5465145, 5431529, 5322450, 5503388, 5268049, 5338021, 5091735,
        7634757, 7461203, 7457022, 7626448, 7673417, 7643183, 7716373, 7656655, 7832666, 7638866, 7512219
    ],
    "Trabajadores subordinados y remunerados": [
        16680615, 16722662, 16621848, 16640219, 16406284, 16347762, 16250454, 16013457, 15435367, 15518663, 15079591,
        24302079, 24311695, 24246442, 24356910, 24060045, 23772826, 23883870, 23761875, 23469660, 23688596, 23306381
    ],
    "No remunerados": [
        1355140, 1269247, 1310327, 1349002, 1415572, 1352868, 1343425, 1477694, 1454228, 1363242, 1284699,
        864648, 831012, 840785, 887285, 944901, 904181, 888943, 965895, 1043119, 886465, 92485
    ],
    "Genero": [
        "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer",
        "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre"
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Sumar los totales por género
suma_por_genero = df.groupby("Genero")[["Empleadores", "Trabajadores por cuenta propia", "Trabajadores subordinados y remunerados", "No remunerados"]].sum()

# Convertir a porcentaje (normalizar por fila)
suma_por_genero_porcentajes = suma_por_genero.div(suma_por_genero.sum(axis=1), axis=0) * 100

# Crear colores contrastantes en tonos pastel (incluyendo azul marino)
colors = ["#1f4e79", "#87CEEB", "#B0E0E6", "#ADD8E6"]

# Graficar
ax = suma_por_genero_porcentajes.plot(
    kind="barh",  # Gráfico de barras horizontales
    stacked=True,
    figsize=(9, 6),  # Más alto y menos ancho
    width=0.6,  # Hacer las barras más delgadas
    color=colors,
    alpha=0.9
)

# Agregar los porcentajes fuera de las barras en color negro
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    if width > 0:
        ax.text(
            x + width + 0.5,  # Colocar el valor fuera de la barra
            y + height / 2,
            f'{width:.1f}%',  # Mostrar el porcentaje
            ha='left',  # Alineado a la izquierda
            va='center',
            color='black',  # Color negro
            fontsize=10
        )

# Personalización
plt.title("Puesto que ocupan las personas\n(como % Personas Ocupadas)\nEnero 2022 a Agosto 2024", fontsize=14, pad=20)
plt.xlabel("Porcentaje (%)", fontsize=10)
plt.ylabel("Género", fontsize=10, labelpad=15)
plt.xticks(fontsize=8)  # Hacer las etiquetas del eje X más pequeñas
plt.yticks(fontsize=10)  # Ajustar tamaño de las etiquetas del eje Y
plt.legend(
    title="Posición en la ocupación",
    loc="lower center",
    bbox_to_anchor=(0.5, -0.15),  # Leyenda separada debajo del gráfico
    ncol=2,
    fontsize=8
)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos en un diccionario
data = {
    "Trimestre": [
        "Tercer trimestre del 2024", "Segundo trimestre del 2024", "Primer trimestre del 2024",
        "Cuarto trimestre del 2023", "Tercer trimestre del 2023", "Segundo trimestre del 2023",
        "Primer trimestre del 2023", "Cuarto trimestre del 2022", "Tercer trimestre del 2022",
        "Segundo trimestre del 2022", "Primer trimestre del 2022", "Tercer trimestre del 2024",
        "Segundo trimestre del 2024", "Primer trimestre del 2024", "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023", "Segundo trimestre del 2023", "Primer trimestre del 2023",
        "Cuarto trimestre del 2022", "Tercer trimestre del 2022", "Segundo trimestre del 2022",
        "Primer trimestre del 2022"
    ],
    "Total": [
        24272864, 24279108, 24049349, 24241480, 24018262, 23805405, 23605572, 23653813, 22808402, 22891895, 22081189,
        35255385, 35048053, 35071556, 35162467, 35149210, 34716585, 34886554, 34695540, 34632039, 34528782, 33997934
    ],
    "Empleadores": [
        713359, 746, 771471, 701401, 731261, 673246, 689243, 659274, 650758, 671969, 625164,
        2453901, 2444143, 2527307, 2291824, 2470847, 2396395, 2397368, 2311115, 2286594, 2314855, 2254484
    ],
    "Trabajadores por cuenta propia": [
        5523750, 5541199, 5345703, 5550858, 5465145, 5431529, 5322450, 5503388, 5268049, 5338021, 5091735,
        7634757, 7461203, 7457022, 7626448, 7673417, 7643183, 7716373, 7656655, 7832666, 7638866, 7512219
    ],
    "Trabajadores subordinados y remunerados": [
        16680615, 16722662, 16621848, 16640219, 16406284, 16347762, 16250454, 16013457, 15435367, 15518663, 15079591,
        24302079, 24311695, 24246442, 24356910, 24060045, 23772826, 23883870, 23761875, 23469660, 23688596, 23306381
    ],
    "No remunerados": [
        1355140, 1269247, 1310327, 1349002, 1415572, 1352868, 1343425, 1477694, 1454228, 1363242, 1284699,
        864648, 831012, 840785, 887285, 944901, 904181, 888943, 965895, 1043119, 886465, 92485
    ],
    "Genero": [
        "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer",
        "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre"
    ]
}

colors = ["#1f4e79", "#87CEEB", "#5F9EA0", "#4682B4"]


# Crear el DataFrame
df = pd.DataFrame(data)

# Graficar
ax = suma_por_genero_porcentajes.plot(
    kind="barh",  # Gráfico de barras horizontales
    stacked=True,
    figsize=(9, 6),  # Más alto y menos ancho
    width=0.3,  # Hacer las barras más delgadas
    color=colors,
    alpha=0.9
)

# Agregar los porcentajes fuera de las barras, encima de cada proporción
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    if width > 0:
        ax.text(
            x + width / 2,  # Colocar el valor fuera del gráfico de barras
                       y + height +0.1,  # Posicionar el texto arriba de la barra

            f'{width:.1f}%',  # Mostrar el porcentaje
            ha='left',  # Alineado a la izquierda
            va='center',  # Alineado verticalmente en el centro
            color='black',  # Color negro
            fontsize=10
        )

# Personalización
plt.title("Puesto que ocupan las personas\n(como % Personas Ocupadas)\nEnero 2022 a Agosto 2024", fontsize=14, pad=20)
plt.xlabel("Porcentaje (%)", fontsize=10)
plt.ylabel("Género", fontsize=10, labelpad=15)
plt.xticks(fontsize=8)  # Hacer las etiquetas del eje X más pequeñas
plt.yticks(fontsize=10)  # Ajustar tamaño de las etiquetas del eje Y
plt.legend(
    title="Posición en la ocupación",
    loc="lower center",
    bbox_to_anchor=(0.5, -0.30),  # Leyenda separada debajo del gráfico
    ncol=2,
    fontsize=8
)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos en un diccionario
data = {
    "Trimestre": [
        "Tercer trimestre del 2024", "Segundo trimestre del 2024", "Primer trimestre del 2024",
        "Cuarto trimestre del 2023", "Tercer trimestre del 2023", "Segundo trimestre del 2023",
        "Primer trimestre del 2023", "Cuarto trimestre del 2022", "Tercer trimestre del 2022",
        "Segundo trimestre del 2022", "Primer trimestre del 2022", "Tercer trimestre del 2024",
        "Segundo trimestre del 2024", "Primer trimestre del 2024", "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023", "Segundo trimestre del 2023", "Primer trimestre del 2023",
        "Cuarto trimestre del 2022", "Tercer trimestre del 2022", "Segundo trimestre del 2022",
        "Primer trimestre del 2022"
    ],
    "Total": [
        24272864, 24279108, 24049349, 24241480, 24018262, 23805405, 23605572, 23653813, 22808402, 22891895, 22081189,
        35255385, 35048053, 35071556, 35162467, 35149210, 34716585, 34886554, 34695540, 34632039, 34528782, 33997934
    ],
    "Empleadores": [
        713359, 746, 771471, 701401, 731261, 673246, 689243, 659274, 650758, 671969, 625164,
        2453901, 2444143, 2527307, 2291824, 2470847, 2396395, 2397368, 2311115, 2286594, 2314855, 2254484
    ],
    "Trabajadores por cuenta propia": [
        5523750, 5541199, 5345703, 5550858, 5465145, 5431529, 5322450, 5503388, 5268049, 5338021, 5091735,
        7634757, 7461203, 7457022, 7626448, 7673417, 7643183, 7716373, 7656655, 7832666, 7638866, 7512219
    ],
    "Trabajadores subordinados y remunerados": [
        16680615, 16722662, 16621848, 16640219, 16406284, 16347762, 16250454, 16013457, 15435367, 15518663, 15079591,
        24302079, 24311695, 24246442, 24356910, 24060045, 23772826, 23883870, 23761875, 23469660, 23688596, 23306381
    ],
    "No remunerados": [
        1355140, 1269247, 1310327, 1349002, 1415572, 1352868, 1343425, 1477694, 1454228, 1363242, 1284699,
        864648, 831012, 840785, 887285, 944901, 904181, 888943, 965895, 1043119, 886465, 92485
    ],
    "Genero": [
        "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer",
        "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre"
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Sumar los totales por género
suma_por_genero = df.groupby("Genero")[["Empleadores", "Trabajadores por cuenta propia", "Trabajadores subordinados y remunerados", "No remunerados"]].sum()

# Convertir a porcentaje (normalizar por fila)
suma_por_genero_porcentajes = suma_por_genero.div(suma_por_genero.sum(axis=1), axis=0) * 100

# Crear colores contrastantes en tonos pastel (incluyendo azul marino)
colors = ["#1f4e79", "#87CEEB", "#B0E0E6", "#ADD8E6"]

# Graficar
ax = suma_por_genero_porcentajes.plot(
    kind="barh",  # Gráfico de barras horizontales
    stacked=True,
    figsize=(6, 10),  # Más alto y menos ancho
    width=0.5,  # Hacer las barras más delgadas
    color=colors,
    alpha=0.9
)

# Agregar los porcentajes al lado de las barras
for i, row in suma_por_genero_porcentajes.iterrows():
    cum_width = 0
    for col, value in row.iteritems():
        ax.text(
            x=cum_width + value / 2,
            y=i, 
            s=f'{value:.1f}%', 
            color='black',
            fontsize=8,
            va='center'
        )
        cum_width += value

# Personalización
plt.title("Puesto que ocupan las personas\n(como % Personas Ocupadas)\nEnero 2022 a Agosto 2024", fontsize=14, pad=20)
plt.xlabel("Porcentaje (%)", fontsize=10)
plt.ylabel("Género", fontsize=10, labelpad=15)
plt.xticks(fontsize=8)  # Hacer las etiquetas del eje X más pequeñas
plt.yticks(fontsize=10)  # Ajustar tamaño de las etiquetas del eje Y
plt.legend(
    title="Posición en la ocupación",
    loc="lower center",
    bbox_to_anchor=(0.5, -0.15),  # Leyenda separada debajo del gráfico
    ncol=2,
    fontsize=8
)
plt.tight_layout()

# Mostrar la gráfica
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 67
#      65 for i, row in suma_por_genero_porcentajes.iterrows():
#      66     cum_width = 0
# ---> 67     for col, value in row.iteritems():
#      68         ax.text(
#      69             x=cum_width + value / 2,
#      70             y=i,
#    (...)
#      74             va='center'
#      75         )
#      76         cum_width += value
#
# File /opt/anaconda3/envs/estancia_investigacion/lib/python3.9/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos en un diccionario
data = {
    "Trimestre": [
        "Tercer trimestre del 2024", "Segundo trimestre del 2024", "Primer trimestre del 2024",
        "Cuarto trimestre del 2023", "Tercer trimestre del 2023", "Segundo trimestre del 2023",
        "Primer trimestre del 2023", "Cuarto trimestre del 2022", "Tercer trimestre del 2022",
        "Segundo trimestre del 2022", "Primer trimestre del 2022", "Tercer trimestre del 2024",
        "Segundo trimestre del 2024", "Primer trimestre del 2024", "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023", "Segundo trimestre del 2023", "Primer trimestre del 2023",
        "Cuarto trimestre del 2022", "Tercer trimestre del 2022", "Segundo trimestre del 2022",
        "Primer trimestre del 2022"
    ],
    "Total": [
        24272864, 24279108, 24049349, 24241480, 24018262, 23805405, 23605572, 23653813, 22808402, 22891895, 22081189,
        35255385, 35048053, 35071556, 35162467, 35149210, 34716585, 34886554, 34695540, 34632039, 34528782, 33997934
    ],
    "Empleadores": [
        713359, 746, 771471, 701401, 731261, 673246, 689243, 659274, 650758, 671969, 625164,
        2453901, 2444143, 2527307, 2291824, 2470847, 2396395, 2397368, 2311115, 2286594, 2314855, 2254484
    ],
    "Trabajadores por cuenta propia": [
        5523750, 5541199, 5345703, 5550858, 5465145, 5431529, 5322450, 5503388, 5268049, 5338021, 5091735,
        7634757, 7461203, 7457022, 7626448, 7673417, 7643183, 7716373, 7656655, 7832666, 7638866, 7512219
    ],
    "Trabajadores subordinados y remunerados": [
        16680615, 16722662, 16621848, 16640219, 16406284, 16347762, 16250454, 16013457, 15435367, 15518663, 15079591,
        24302079, 24311695, 24246442, 24356910, 24060045, 23772826, 23883870, 23761875, 23469660, 23688596, 23306381
    ],
    "No remunerados": [
        1355140, 1269247, 1310327, 1349002, 1415572, 1352868, 1343425, 1477694, 1454228, 1363242, 1284699,
        864648, 831012, 840785, 887285, 944901, 904181, 888943, 965895, 1043119, 886465, 92485
    ],
    "Genero": [
        "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer",
        "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre"
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Sumar los totales por género
suma_por_genero = df.groupby("Genero")[["Empleadores", "Trabajadores por cuenta propia", "Trabajadores subordinados y remunerados", "No remunerados"]].sum()

# Convertir a porcentaje (normalizar por fila)
suma_por_genero_porcentajes = suma_por_genero.div(suma_por_genero.sum(axis=1), axis=0) * 100

# Crear colores contrastantes en tonos pastel (incluyendo azul marino)
colors = ["#1f4e79", "#87CEEB", "#B0E0E6", "#ADD8E6"]

# Graficar
ax = suma_por_genero_porcentajes.plot(
    kind="barh",  # Gráfico de barras horizontales
    stacked=True,
    figsize=(6, 10),  # Más alto y menos ancho
    width=0.5,  # Hacer las barras más delgadas
    color=colors,
    alpha=0.9
)

# Agregar los porcentajes al lado de las barras
for i, row in suma_por_genero_porcentajes.iterrows():
    cum_width = 0
    for col, value in row.iteritems():
        ax.text(
            x=cum_width + value / 2,
            y=i, 
            s=f'{value:.1f}%', 
            color='black',
            fontsize=8,
            va='center'
        )
        cum_width += value

# Personalización
plt.title("Puesto que ocupan las personas\n(como % Personas Ocupadas)\nEnero 2022 a Agosto 2024", fontsize=14, pad=20)
plt.xlabel("Porcentaje (%)", fontsize=10)
plt.ylabel("Género", fontsize=10, labelpad=15)
plt.xticks(fontsize=8)  # Hacer las etiquetas del eje X más pequeñas
plt.yticks(fontsize=10)  # Ajustar tamaño de las etiquetas del eje Y
plt.legend(
    title="Posición en la ocupación",
    loc="lower center",
    bbox_to_anchor=(0.5, -0.15),  # Leyenda separada debajo del gráfico
    ncol=2,
    fontsize=8
)
plt.tight_layout()

# Mostrar la gráfica
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 67
#      65 for i, row in suma_por_genero_porcentajes.iterrows():
#      66     cum_width = 0
# ---> 67     for col, value in row.iteritems():
#      68         ax.text(
#      69             x=cum_width + value / 2,
#      70             y=i,
#    (...)
#      74             va='center'
#      75         )
#      76         cum_width += value
#
# File /opt/anaconda3/envs/estancia_investigacion/lib/python3.9/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos en un diccionario
data = {
    "Trimestre": [
        "Tercer trimestre del 2024", "Segundo trimestre del 2024", "Primer trimestre del 2024",
        "Cuarto trimestre del 2023", "Tercer trimestre del 2023", "Segundo trimestre del 2023",
        "Primer trimestre del 2023", "Cuarto trimestre del 2022", "Tercer trimestre del 2022",
        "Segundo trimestre del 2022", "Primer trimestre del 2022", "Tercer trimestre del 2024",
        "Segundo trimestre del 2024", "Primer trimestre del 2024", "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023", "Segundo trimestre del 2023", "Primer trimestre del 2023",
        "Cuarto trimestre del 2022", "Tercer trimestre del 2022", "Segundo trimestre del 2022",
        "Primer trimestre del 2022"
    ],
    "Total": [
        24272864, 24279108, 24049349, 24241480, 24018262, 23805405, 23605572, 23653813, 22808402, 22891895, 22081189,
        35255385, 35048053, 35071556, 35162467, 35149210, 34716585, 34886554, 34695540, 34632039, 34528782, 33997934
    ],
    "Empleadores": [
        713359, 746, 771471, 701401, 731261, 673246, 689243, 659274, 650758, 671969, 625164,
        2453901, 2444143, 2527307, 2291824, 2470847, 2396395, 2397368, 2311115, 2286594, 2314855, 2254484
    ],
    "Trabajadores por cuenta propia": [
        5523750, 5541199, 5345703, 5550858, 5465145, 5431529, 5322450, 5503388, 5268049, 5338021, 5091735,
        7634757, 7461203, 7457022, 7626448, 7673417, 7643183, 7716373, 7656655, 7832666, 7638866, 7512219
    ],
    "Trabajadores subordinados y remunerados": [
        16680615, 16722662, 16621848, 16640219, 16406284, 16347762, 16250454, 16013457, 15435367, 15518663, 15079591,
        24302079, 24311695, 24246442, 24356910, 24060045, 23772826, 23883870, 23761875, 23469660, 23688596, 23306381
    ],
    "No remunerados": [
        1355140, 1269247, 1310327, 1349002, 1415572, 1352868, 1343425, 1477694, 1454228, 1363242, 1284699,
        864648, 831012, 840785, 887285, 944901, 904181, 888943, 965895, 1043119, 886465, 92485
    ],
    "Genero": [
        "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer", "mujer",
        "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre", "hombre"
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Sumar los totales por género
suma_por_genero = df.groupby("Genero")[["Empleadores", "Trabajadores por cuenta propia", "Trabajadores subordinados y remunerados", "No remunerados"]].sum()

# Convertir a porcentaje (normalizar por fila)
suma_por_genero_porcentajes = suma_por_genero.div(suma_por_genero.sum(axis=1), axis=0) * 100

# Graficar
ax = suma_por_genero_porcentajes.plot(
    kind="bar",
    stacked=True,
    figsize=(10, 6),
    color=plt.cm.Blues(range(50, 250, 50)),  # Escala de azules
    alpha=0.85
)

# Agregar los porcentajes dentro de las barras
for p in ax.patches:
    height = p.get_height()
    width = p.get_width()
    x, y = p.get_xy()
    if height > 0:
        ax.text(x + width / 2, y + height / 2, f'{height:.2f}%', ha='center', va='center', color='white', fontsize=12)

# Personalización
plt.title("Distribución porcentual por posición en la ocupación y género", fontsize=16)
plt.ylabel("Porcentaje (%)", fontsize=12)
plt.xlabel("Género", fontsize=12)
plt.xticks(rotation=0, fontsize=12)
plt.legend(title="Posición en la ocupación", loc="lower center", bbox_to_anchor=(0.5, -0.25), ncol=2, fontsize=10)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %%
d=pd.read_parquet('/Users/delia.cardenas/Downloads/specific_case_2024-12-06.parquet')
d
# Out:
#    application_id  entity_id  user_id  date_query date_execution  \
# 0         2252422    2435131  2256458  2024-10-24     2024-10-24
#
#                                         des_features  num_prediction  \
# 0  {'UTILIDAD_FISCAL_ABOVE_THR': nan, 'TIA': 4794...          0.1439
#
#   des_risk_tier                                    des_shap_values  \
# 0            AA  {'UTILIDAD_FISCAL_ABOVE_THR': 0.02527586478660...
#
#    flag_is_active
# 0           False

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos iniciales
data = {
    "Periodo encuesta": [
        "Tercer trimestre del 2024",
        "Segundo trimestre del 2024",
        "Primer trimestre del 2024",
        "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023",
        "Segundo trimestre del 2023",
        "Primer trimestre del 2023",
        "Cuarto trimestre del 2022",
        "Tercer trimestre del 2022",
        "Segundo trimestre del 2022",
    ],
    "Total": [
        59528249, 59327161, 59120905, 59403947, 59167472, 
        58521990, 58492126, 58349353, 57440441, 57420677
    ],
    "Trabajadores independientes": [
        16325767, 16192545, 16101503, 16170531, 16340670, 
        16144353, 16125434, 16130432, 16038067, 15963711
    ],
    "Trabajadores subordinados y remunerados": [
        40982694, 41034357, 40868290, 40997129, 40466329, 
        40120588, 40134324, 39775332, 38905027, 39207259
    ],
    "Trabajadores no remunerados": [
        2219788, 2100259, 2151112, 2236287, 2360473, 
        2257049, 2232368, 2443589, 2497347, 2249707
    ],
}

# Crear DataFrame
df = pd.DataFrame(data)

# Sumar los valores totales por categoría
totales = {
    "Trabajadores independientes": df["Trabajadores independientes"].sum(),
    "Trabajadores subordinados y remunerados": df["Trabajadores subordinados y remunerados"].sum(),
    "Trabajadores no remunerados": df["Trabajadores no remunerados"].sum(),
}

# Calcular el total global
total_global = sum(totales.values())

# Calcular porcentajes
porcentajes = {k: (v / total_global) * 100 for k, v in totales.items()}

# Crear gráfica
fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(porcentajes.keys(), porcentajes.values(), color=["#1f77b4", "#ff7f0e", "#2ca02c"])
ax.set_ylabel("Porcentaje (%)")
ax.set_title("Distribución porcentual total por tipo de ocupación")
ax.set_ylim(0, 100)

# Mostrar los valores en la parte superior de las barras
for i, v in enumerate(porcentajes.values()):
    ax.text(i, v + 1, f"{v:.2f}%", ha="center", fontsize=10)

plt.tight_layout()
plt.show()

# Mostrar los totales y porcentajes en consola
print("Totales por categoría:")
print(totales)
print("\nPorcentajes:")
print(porcentajes)
# Out:
# Totales por categoría:
# {'Trabajadores independientes': 161533013, 'Trabajadores subordinados y remunerados': 402491329, 'Trabajadores no remunerados': 22747979}
#
# Porcentajes:
# {'Trabajadores independientes': 27.529078523115952, 'Trabajadores subordinados y remunerados': 68.59412323915667, 'Trabajadores no remunerados': 3.8767982377273724}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos iniciales
data = {
    "Periodo encuesta": [
        "Tercer trimestre del 2024",
        "Segundo trimestre del 2024",
        "Primer trimestre del 2024",
        "Cuarto trimestre del 2023",
        "Tercer trimestre del 2023",
        "Segundo trimestre del 2023",
        "Primer trimestre del 2023",
        "Cuarto trimestre del 2022",
        "Tercer trimestre del 2022",
        "Segundo trimestre del 2022",
        "Primer trimestre del 2022",
    ],
    "Total": [
        59528249, 59327161, 59120905, 59403947, 59167472,
        58521990, 58492126, 58349353, 57440441, 57420677, 56079123
    ],
    "Trabajadores independientes": [
        16325767, 16192545, 16101503, 16170531, 16340670,
        16144353, 16125434, 16130432, 16038067, 15963711, 15483602
    ],
    "Trabajadores subordinados y remunerados": [
        40982694, 41034357, 40868290, 40997129, 40466329,
        40120588, 40134324, 39775332, 38905027, 39207259, 38385972
    ],
    "Trabajadores no remunerados": [
        2219788, 2100259, 2151112, 2236287, 2360473,
        2257049, 2232368, 2443589, 2497347, 2249707, 2209549
    ],
}

# Crear DataFrame
df = pd.DataFrame(data)

# Sumar los valores totales por categoría
totales = {
    "Trabajadores independientes": df["Trabajadores independientes"].sum(),
    "Trabajadores subordinados y remunerados": df["Trabajadores subordinados y remunerados"].sum(),
    "Trabajadores no remunerados": df["Trabajadores no remunerados"].sum(),
}

# Calcular el total global
total_global = sum(totales.values())

# Calcular porcentajes
porcentajes = {k: (v / total_global) * 100 for k, v in totales.items()}

# Crear gráfica
fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(porcentajes.keys(), porcentajes.values(), color=["#1f77b4", "#ff7f0e", "#2ca02c"])
ax.set_ylabel("Porcentaje (%)")
ax.set_title("Distribución porcentual total por tipo de ocupación")
ax.set_ylim(0, 100)

# Mostrar los valores en la parte superior de las barras
for i, v in enumerate(porcentajes.values()):
    ax.text(i, v + 1, f"{v:.2f}%", ha="center", fontsize=10)

plt.tight_layout()
plt.show()

# Mostrar los totales y porcentajes en consola
print("Totales por categoría:")
print(totales)
print("\nPorcentajes:")
print(porcentajes)
# Out:
# Totales por categoría:
# {'Trabajadores independientes': 177016615, 'Trabajadores subordinados y remunerados': 440877301, 'Trabajadores no remunerados': 24957528}
#
# Porcentajes:
# {'Trabajadores independientes': 27.536161993905388, 'Trabajadores subordinados y remunerados': 68.58152145645643, 'Trabajadores no remunerados': 3.8823165496381775}

# %%
m=pd.read_excel('/Users/delia.cardenas/Downloads/INEGI_exporta_3_12_2024_17_43_51.xls')
m
# Out:
#                                     Población ocupada Unnamed: 1  \
# 0                                        Sexo : Total        NaN
# 1                                                 NaN        NaN
# 2   Consulta de: Población ocupada   Por: Periodo ...        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN      Total
# ..                                                ...        ...
# 92  - A partir del primer trimestre de 2021 y del ...        NaN
# 93                                                NaN        NaN
# 94  - Se precisa que, a partir del 31 de enero de ...        NaN
# 95                                                NaN        NaN
# 96  - Derivado del desastre natural ocasionado por...        NaN
#
#                                  Unnamed: 2                   Unnamed: 3  \
# 0                                       NaN                          NaN
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dic=pd.read_csv('/Users/delia.cardenas/Downloads/conjunto_de_datos_enoe_2024_3t_csv/conjunto_de_datos_sdem_enoe_2024_3t/diccionario_de_datos/diccionario_datos_sdem_enoe_2024_3t.csv')
list(dic['NOMBRE_CAMPO'])
# Out:
# ['Resultado definitivo de la entrevista',
#  'Número de la localidad',
#  'Número de municipio según entidad',
#  'Estrato nacional y estatal',
#  'Estrato de diseño trimestral',
#  'Estrato de diseño mensual',
#  'Número de ageb del marco nacional',
#  'Tamaño de localidad trimestral',
#  'Tamaño de localidad mensual',
#  'Ciudad autorrepresentada',
#  'Entidad',
#  'Control',
#  'Unidad primaria de muestreo',
#  'Distribución semanal',
#  'Número progresivo de la vivienda',
#  'Vivienda seleccionada',
#  'Número de hogar',
#  'Hogar mudado',
#  'Número de entrevista o visita',
#  'Periodo',
#  'Número de renglón',
#  'Pregunta 6 Condición de residencia',
#  'Pregunta 7 Clave de parentesco',
#  'Pregunta 8 Sexo',
#  'Pregunta 9 Edad',
#  'Pregunta 10 Día de nacimiento',
#  'Pregunta 10 Mes de nacimiento',
#  'Pregunta 10 Año de nacimiento',
#  'Pregunta 11 Clave de lugar de nacimiento',
#  'Pregunta 12  ¿Sabe leer y escribir un recado...?',
# ...

# %%
dic=pd.read_csv('/Users/delia.cardenas/Downloads/conjunto_de_datos_enoe_2024_3t_csv/conjunto_de_datos_coe1_enoe_2024_3t/diccionario_de_datos/diccionario_datos_coe1_enoe_2024_3t.csv')
dic['NOMBRE_CAMPO'].unique()
# Out:
# array(['Resultado definitivo de la entrevista',
#        'Ciudad autorrepresentada', 'Entidad', 'Control',
#        'Unidad primaria de muestreo', 'Distribución semanal',
#        'Número progresivo de la vivienda', 'Vivienda Seleccionada',
#        'Número de hogar', 'Hogar mudado', 'Número de entrevista o visita',
#        'Periodo', 'Número de renglón', 'Edad', 'Renglón del Informante',
#        'Pregunta 1 Ahora le voy a preguntar por la situación laboral de ...¿La semana pasada trabajó por lo menos una hora?',
#        'Pregunta 1a Opción 1: realizar una actividad que le proporcionó ingresos?',
#        'Pregunta 1a Opción 2: ayudar en las tierras o en el negocio de un familiar o de otra persona?',
#        'Pregunta 1a Opción 3: no trabajó la semana pasada',
#        'Pregunta 1b Aunque ya me dijo que ... no trabajó la semana pasada,  ¿tiene algún empleo, negocio o realiza alguna actividad por su cuenta?',
# ...

# %%
import pandas as pd
d=pd.read_csv('/Users/delia.cardenas/Downloads/conjunto_de_datos_enoe_2024_3t_csv/conjunto_de_datos_coe1_enoe_2024_3t/conjunto_de_datos/conjunto_de_datos_coe1_enoe_2024_3t.csv')
d
# Out:
#         r_def  cd_a  ent    con      upm  d_sem  n_pro_viv  v_sel  n_hog  \
# 0           0     1    9  40001   900987    101         52      2      1
# 1           0     1    9  40001   900987    101         52      2      1
# 2           0     1    9  40001   900987    101         86      3      1
# 3           0     1    9  40001   900987    101         86      3      1
# 4           0     1    9  40001   900987    101         86      3      1
# ...       ...   ...  ...    ...      ...    ...        ...    ...    ...
# 347253      0    86   32  60078  3260119    301         83     60      1
# 347254      0    86   32  60078  3260119    301         83     60      1
# 347255      0    86   32  60078  3260119    301         83     60      1
# 347256      0    86   32  60078  3260119    301         83     60      1
# 347257      0    86   32  60078  3260119    301         83     60      1
#
#         h_mud  ...  p5f12  p5f13  p5f14  p5f15  p5f99  ur tipo mes_cal  \
# ...

# %%
list(d)
# Out:
# ['r_def',
#  'cd_a',
#  'ent',
#  'con',
#  'upm',
#  'd_sem',
#  'n_pro_viv',
#  'v_sel',
#  'n_hog',
#  'h_mud',
#  'n_ent',
#  'per',
#  'n_ren',
#  'eda',
#  'n_inf',
#  'p1',
#  'p1a1',
#  'p1a2',
#  'p1a3',
#  'p1b',
#  'p1c',
#  'p1d',
#  'p1e',
#  'p2_1',
#  'p2_2',
#  'p2_3',
#  'p2_4',
#  'p2_9',
#  'p2a_dia',
#  'p2a_sem',
#  'p2a_mes',
#  'p2a_anio',
#  'p2b_dia',
#  'p2b_sem',
#  'p2b_mes',
#  'p2b_anio',
#  'p2b',
#  'p2c',
#  'p2d1',
#  'p2d2',
#  'p2d3',
#  'p2d4',
#  'p2d5',
#  'p2d6',
#  'p2d7',
#  'p2d8',
#  'p2d9',
#  'p2d10',
#  'p2d11',
#  'p2d99',
#  'p2e',
#  'p2f',
#  'p2g1',
#  'p2g2',
#  'p2h1',
#  'p2h2',
#  'p2h3',
#  'p2h4',
#  'p2h9',
#  'p2i',
#  'p2j',
#  'p2k_anio',
#  'p2k_mes',
#  'p2k',
#  'p3',
#  'p3a',
#  'p3b',
#  'p3c1',
#  'p3c2',
#  'p3c3',
#  'p3c4',
#  'p3c9',
#  'p3d',
#  'p3e',
#  'p3f1',
#  'p3f2',
#  'p3g1_1',
#  'p3g1_2',
#  'p3g2_1',
#  'p3g2_2',
#  'p3g3_1',
#  'p3g3_2',
#  'p3g4_1',
#  'p3g4_2',
#  'p3g9',
#  'p3g_tot',
#  'p3h',
# ...
